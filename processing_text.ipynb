# %% [markdown]
# # INSTRUCTIONS
# This Jupyter Notebook is for the A4 assignment of collecting data.
#
# I used the full speeches that Donald Trump gave at 35 of his rallies until 2021.

# %%
# Import spacy
import spacy

# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.graph_objects as go
import plotly.express as px

# %%
# Create empty lists for file names and contents
texts = []
file_names = []

# Iterate through each file in the folder
for _file_name in os.listdir('archive'):
# Look for only text files
    if _file_name.endswith('.txt'):
    # Append contents of each text file to text list
        texts.append(open('archive' + '/' + _file_name, 'r', encoding='utf-8').read())
        # Append name of each file to file name list
        file_names.append(_file_name)

# %%
# Create dictionary object associating each file name with its text
d = {'Filename':file_names,'Text':texts}

# %%
# Turn dictionary into a dataframe
speech_df = pd.DataFrame(d)

# %%
speech_df.head()
# Out:
#                      Filename  \
# 0   FayettevilleSep9_2019.txt
# 1         TupeloNov1_2019.txt
# 2  NewHampshireAug15_2019.txt
# 3     HendersonSep13_2020.txt
# 4          OhioSep21_2020.txt
#
#                                                 Text
# 0   Thank you everybody. Thank you and Vice Presi...
# 1  ell, thank you very much. And hello, Tupelo. T...
# 2   Thank you very much everybody. Thank you. Wow...
# 3  Thank you, thank you. Wow. Wow, and I'm thrill...
# 4  Wow, that's a big crowd. This is a big crowd. ...

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %%
# Apply the function to the "Text" column, so that the nlp pipeline is called on each speech
speech_df['Doc'] = speech_df['Text'].apply(process_text)

# %%
speech_df.head(5)
# Out:
#                      Filename  \
# 0   FayettevilleSep9_2019.txt
# 1         TupeloNov1_2019.txt
# 2  NewHampshireAug15_2019.txt
# 3     HendersonSep13_2020.txt
# 4          OhioSep21_2020.txt
#
#                                                 Text  \
# 0   Thank you everybody. Thank you and Vice Presi...
# 1  ell, thank you very much. And hello, Tupelo. T...
# 2   Thank you very much everybody. Thank you. Wow...
# 3  Thank you, thank you. Wow. Wow, and I'm thrill...
# 4  Wow, that's a big crowd. This is a big crowd. ...
#
#                                                  Doc
# 0  ( , Thank, you, everybody, ., Thank, you, and,...
# 1  (ell, ,, thank, you, very, much, ., And, hello...
# 2  ( , Thank, you, very, much, everybody, ., Than...
# 3  (Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  (Wow, ,, that, 's, a, big, crowd, ., This, is,...

# %%
# Define a function to retrieve tokens from a doc object
def get_token(doc):
    return [(token.text) for token in doc]

# %%
# Run the token retrieval function on the doc objects in the dataframe
speech_df['Tokens'] = speech_df['Doc'].apply(get_token)
speech_df.head()
# Out:
#                      Filename  \
# 0   FayettevilleSep9_2019.txt
# 1         TupeloNov1_2019.txt
# 2  NewHampshireAug15_2019.txt
# 3     HendersonSep13_2020.txt
# 4          OhioSep21_2020.txt
#
#                                                 Text  \
# 0   Thank you everybody. Thank you and Vice Presi...
# 1  ell, thank you very much. And hello, Tupelo. T...
# 2   Thank you very much everybody. Thank you. Wow...
# 3  Thank you, thank you. Wow. Wow, and I'm thrill...
# 4  Wow, that's a big crowd. This is a big crowd. ...
#
#                                                  Doc  \
# 0  ( , Thank, you, everybody, ., Thank, you, and,...
# 1  (ell, ,, thank, you, very, much, ., And, hello...
# 2  ( , Thank, you, very, much, everybody, ., Than...
# 3  (Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  (Wow, ,, that, 's, a, big, crowd, ., This, is,...
#
#                                               Tokens
# 0  [ , Thank, you, everybody, ., Thank, you, and,...
# 1  [ell, ,, thank, you, very, much, ., And, hello...
# 2  [ , Thank, you, very, much, everybody, ., Than...
# 3  [Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  [Wow, ,, that, 's, a, big, crowd, ., This, is,...

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
speech_df['Lemmas'] = speech_df['Doc'].apply(get_lemma)
speech_df.head(5)
# Out:
#                      Filename  \
# 0   FayettevilleSep9_2019.txt
# 1         TupeloNov1_2019.txt
# 2  NewHampshireAug15_2019.txt
# 3     HendersonSep13_2020.txt
# 4          OhioSep21_2020.txt
#
#                                                 Text  \
# 0   Thank you everybody. Thank you and Vice Presi...
# 1  ell, thank you very much. And hello, Tupelo. T...
# 2   Thank you very much everybody. Thank you. Wow...
# 3  Thank you, thank you. Wow. Wow, and I'm thrill...
# 4  Wow, that's a big crowd. This is a big crowd. ...
#
#                                                  Doc  \
# 0  ( , Thank, you, everybody, ., Thank, you, and,...
# 1  (ell, ,, thank, you, very, much, ., And, hello...
# 2  ( , Thank, you, very, much, everybody, ., Than...
# 3  (Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  (Wow, ,, that, 's, a, big, crowd, ., This, is,...
#
#                                               Tokens  \
# 0  [ , Thank, you, everybody, ., Thank, you, and,...
# 1  [ell, ,, thank, you, very, much, ., And, hello...
# 2  [ , Thank, you, very, much, everybody, ., Than...
# 3  [Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  [Wow, ,, that, 's, a, big, crowd, ., This, is,...
#
#                                               Lemmas
# 0  [ , thank, you, everybody, ., thank, you, and,...
# 1  [ell, ,, thank, you, very, much, ., and, hello...
# 2  [ , thank, you, very, much, everybody, ., than...
# 3  [thank, you, ,, thank, you, ., wow, ., wow, ,,...
# 4  [wow, ,, that, be, a, big, crowd, ., this, be,...

# %%
# Define a function to retrieve lemmas from a doc object
def get_pos(doc):
    return [(token.pos_, token.tag_) for token in doc]

# Define a function to retrieve parts of speech from a doc object
speech_df['POS'] = speech_df['Doc'].apply(get_pos)

# %%
speech_df.head(5)
# Out:
#                      Filename  \
# 0   FayettevilleSep9_2019.txt
# 1         TupeloNov1_2019.txt
# 2  NewHampshireAug15_2019.txt
# 3     HendersonSep13_2020.txt
# 4          OhioSep21_2020.txt
#
#                                                 Text  \
# 0   Thank you everybody. Thank you and Vice Presi...
# 1  ell, thank you very much. And hello, Tupelo. T...
# 2   Thank you very much everybody. Thank you. Wow...
# 3  Thank you, thank you. Wow. Wow, and I'm thrill...
# 4  Wow, that's a big crowd. This is a big crowd. ...
#
#                                                  Doc  \
# 0  ( , Thank, you, everybody, ., Thank, you, and,...
# 1  (ell, ,, thank, you, very, much, ., And, hello...
# 2  ( , Thank, you, very, much, everybody, ., Than...
# 3  (Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  (Wow, ,, that, 's, a, big, crowd, ., This, is,...
#
#                                               Tokens  \
# 0  [ , Thank, you, everybody, ., Thank, you, and,...
# 1  [ell, ,, thank, you, very, much, ., And, hello...
# 2  [ , Thank, you, very, much, everybody, ., Than...
# 3  [Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4  [Wow, ,, that, 's, a, big, crowd, ., This, is,...
#
#                                               Lemmas  \
# 0  [ , thank, you, everybody, ., thank, you, and,...
# 1  [ell, ,, thank, you, very, much, ., and, hello...
# 2  [ , thank, you, very, much, everybody, ., than...
# 3  [thank, you, ,, thank, you, ., wow, ., wow, ,,...
# 4  [wow, ,, that, be, a, big, crowd, ., this, be,...
#
#                                                  POS
# 0  [(SPACE, _SP), (VERB, VBP), (PRON, PRP), (PRON...
# 1  [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 2  [(SPACE, _SP), (VERB, VBP), (PRON, PRP), (ADV,...
# 3  [(VERB, VBP), (PRON, PRP), (PUNCT, ,), (VERB, ...
# 4  [(INTJ, UH), (PUNCT, ,), (PRON, DT), (AUX, VBZ...

# %%
# Define function to extract proper nouns from Doc object
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# Apply function to Doc column and store resulting proper nouns in new column
speech_df['Proper_Nouns'] = speech_df['Doc'].apply(extract_proper_nouns)

# %%
list(speech_df.loc[[3, 34], 'Proper_Nouns'])
# Out:
# [['Henderson',
#   'Nevada',
#   'White',
#   'House',
#   'Los',
#   'Angeles',
#   'God',
#   'America',
#   'hell',
#   'Las',
#   'Vegas',
#   'Sleepy',
#   'Joe',
#   'Biden',
#   'Dana',
#   'White',
#   'Dana',
#   'White',
#   'Sir',
#   'Joe',
#   'Biden',
#   'Joe',
#   'Biden',
#   'Biden',
#   'Biden',
#   'Joe',
#   'Biden',
#   'top-30',
#   'Democrat',
#   'Democrat',
#   'Democrat',
#   'run',
#   'Minneapolis',
#   'National',
#   'Guard',
#   'Seattle',
#   'Seattle',
#   'Portland',
#   'US',
#   'Marshalls',
#   'US',
#   'Marshalls',
#   'Sleepy',
#   'Joe',
#   'Bernie',
#   'Sleepy',
#   'Joe',
#   'Joe',
#   'President',
#   'Xi',
#   'China',
#   'President',
#   'Putin',
#   'Russia',
#   'China',
#   'China',
#   'China',
#   'China',
#   'Europe',
#   'Sleepy',
#   'Joe',
#   'Kim',
#   'Jong',
#   'un',
#   'Kim',
#   'Jong',
#   'un',
#   'Joe',
#   'Joe',
#   'Joe',
#   'New',
#   'York',
#   'New',
#   'York',
#   'New',
#   'York',
#   'New',
#   'York',
#   'Chicago',
#   'Fraternal',
#   'Order',
#   'Police',
#   'Chicago',
#   'Oklahoma',
#   'Texas',
#   'Florida',
#   'New',
#   'York',
#   'Chicago',
#   'Ohio',
#   'New',
#   'York',
#   'Chicago',
#   'Chicago',
#   'Biden',
#   'Republican',
#   'Party',
#   'Biden',
#   'Joe',
#   'Biden',
#   'Boston',
#   'Boston',
#   'Boston',
#   'Bernie',
#   'Sanders',
#   'Crazy',
#   'Bernie',
#   'Crazy',
#   'Bernie',
#   'Boston',
#   'Bernie',
#   'Bernie',
#   'Bernie',
#   'Bernie',
#   'United',
#   'States',
#   'USMCA',
#   'NAFTA',
#   'Biden',
#   'New',
#   'York',
#   'New',
#   'York',
#   'Obama',
#   'Republicans',
#   'Republicans',
#   'Colby',
#   'Colby',
#   'Colby',
#   'Colby',
#   'Biden',
#   'Biden',
#   'Bernie',
#   'Sanders',
#   'Biden',
#   'National',
#   'Troopers',
#   'Association',
#   'Coalition',
#   'Public',
#   'Safety',
#   'Alliance',
#   'Nevada',
#   'Las',
#   'Vegas',
#   'Police',
#   'Protective',
#   'Association',
#   'Nevada',
#   'Steve',
#   'Grammar',
#   'Steve',
#   'Steve',
#   'Steve',
#   'Steve',
#   'Don',
#   'Don',
#   'Joe',
#   'Biden',
#   'America',
#   'defense',
#   'state',
#   'China',
#   'Nevada',
#   'America',
#   'China',
#   'Biden',
#   'China',
#   'Biden',
#   'Biden',
#   'Congressman',
#   'Senator',
#   'Sir',
#   'Us',
#   'Europe',
#   'Mike',
#   'Pence',
#   'Joe',
#   'Biden',
#   'Nancy',
#   'Pelosi',
#   'Chinatown',
#   'Chinatown',
#   'Sleepy',
#   'Joe',
#   'Biden',
#   'America',
#   'China',
#   'America',
#   'America',
#   'America',
#   'America',
#   'Joe',
#   'Biden',
#   'crazy',
#   'Bernie',
#   'S.',
#   'Biden',
#   'America',
#   'America',
#   'America',
#   'Cuomo',
#   'New',
#   'York',
#   'America',
#   'America',
#   'Fredo',
#   'Fredo',
#   'America',
#   'Earth',
#   'God',
#   'America',
#   'Great',
#   'America',
#   'Great',
#   'Comma',
#   'November',
#   'Nevada',
#   'Joe',
#   'Biden',
#   'China',
#   'China',
#   'China',
#   'Nevada',
#   'Biden',
#   'Nevada',
#   'American',
#   'Americans',
#   'Democrats',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'Pennsylvania',
#   'Democrat',
#   'November',
#   'November',
#   'Biden',
#   'Department',
#   'Justice',
#   'Department',
#   'Homeland',
#   'Security',
#   'United',
#   'States',
#   'Supreme',
#   'Court',
#   'Supreme',
#   'Court',
#   'November',
#   'America',
#   'Dan',
#   'Dan',
#   'Rodimer',
#   'Dan',
#   'Rodimer',
#   'Dan',
#   'Rodimer',
#   'Dan',
#   'Jim',
#   'Marchant',
#   'Jim',
#   'Jim',
#   'House',
#   'Nancy',
#   'Pelosi',
#   'Nancy',
#   'Pelosi',
#   'Nancy',
#   'Pelosi',
#   'Michael',
#   'Nevada',
#   'Republican',
#   'Party',
#   'Chairman',
#   'Michael',
#   'McDonald',
#   'Michael',
#   'Attorney',
#   'General',
#   'Adam',
#   'Laxalt',
#   'Kimberly',
#   'Guilfoyle',
#   'Kimberly',
#   'Chicago',
#   'Cubs',
#   'RNC',
#   'Finance',
#   'Chairman',
#   'Todd',
#   'Ricketts',
#   'Todd',
#   'Todd',
#   'Todd',
#   'Rick',
#   'Grenell',
#   'Rick',
#   'Don',
#   'Don',
#   'Las',
#   'Vegas',
#   'Rick',
#   'Harrison',
#   'Rick',
#   'Rick',
#   'Dana',
#   'Dana',
#   'UFC',
#   'Dana',
#   'Dana',
#   'White',
#   'Dana',
#   'Dana',
#   'UFC',
#   'Colby',
#   'Covington',
#   'Colby',
#   'Covington',
#   'Colby',
#   'Covington',
#   'America',
#   'Trump',
#   'America',
#   'Colby',
#   'Covington',
#   'Colby',
#   'Colby',
#   'Henry',
#   'Cejudo',
#   'Henry',
#   'Henry',
#   'Alonzo',
#   'Alonzo',
#   'Cruz',
#   'Alonzo',
#   'Alonzo',
#   'Henry',
#   'Justin',
#   'Gaethje',
#   'Justin',
#   'Justin',
#   'Gaethje',
#   'Justin',
#   'Ali',
#   'Abdelaziz',
#   'UFC',
#   'Dana',
#   'Dana',
#   'West',
#   'California',
#   'FEMA',
#   'Washington',
#   'Oregon',
#   'Oregon',
#   'Portland',
#   'Joe',
#   'Biden',
#   'Biden',
#   'Biden',
#   'Gee',
#   'Amendment',
#   'Beto',
#   "O'Rourke",
#   'Beto',
#   'Green',
#   'New',
#   'Deal',
#   'Green',
#   'New',
#   'Deal',
#   'U.S.',
#   'Trans',
#   '-',
#   'Pacific',
#   'Partnership',
#   'Michigan',
#   'Michigan',
#   'Michigan',
#   'Michigan',
#   'China',
#   'Biden',
#   'China',
#   'USA',
#   'Hispanics',
#   'Latino',
#   'Latino',
#   'Democrats',
#   'Biden',
#   'Hispanic',
#   'Americans',
#   'Little',
#   'Sisters',
#   'Poor',
#   'China',
#   'Democrat',
#   'Party',
#   'Americans',
#   'Border',
#   'Patrol',
#   'Dana',
#   'MS-13',
#   'ICE',
#   'MS-13',
#   'National',
#   'Border',
#   'Patrol',
#   'Council',
#   'Brandon',
#   'Judd',
#   'Art',
#   'Del',
#   'Cueto',
#   'Brandon',
#   'Brandon',
#   'Brandon',
#   'Brandon',
#   'Art',
#   'Colby',
#   'Democrats',
#   'Wall',
#   'US',
#   'US',
#   'Armed',
#   'Forces',
#   'Space',
#   'Force',
#   'VA',
#   'Choice',
#   'VA',
#   'Accountability',
#   'Joe',
#   'Biden',
#   'Iran',
#   'Israel',
#   'Dana',
#   'White',
#   'ISIS',
#   'al',
#   'Baghdadi',
#   'Qasem',
#   'Soleimani',
#   'Israel',
#   'Jerusalem',
#   'Golan',
#   'Heights',
#   'Middle',
#   'East',
#   'United',
#   'Arab',
#   'Emirates',
#   'Bahrain',
#   'Israel',
#   'President',
#   'Nobel',
#   'Prize',
#   'Biden',
#   'President',
#   'Barack',
#   'Hussein',
#   'Obama',
#   'President',
#   'Barack',
#   'Hussein',
#   'Obama',
#   'Nobel',
#   'Peace',
#   'Biden',
#   'Obama',
#   'Rick',
#   'Joe',
#   'Biden',
#   'Biden',
#   'Iraq',
#   'Osama',
#   'bin',
#   'Laden',
#   'Soleimani',
#   'ISIS',
#   'China',
#   'America',
#   'China',
#   'Joe',
#   'Americans',
#   'World',
#   'War',
#   'II',
#   'Europe',
#   'US',
#   'United',
#   'States',
#   'Nevada',
#   'Nevada',
#   '401s',
#   'Americans',
#   'Biden',
#   'America',
#   'Republicans',
#   'Americans',
#   'Washington',
#   'Washington',
#   'Don',
#   'America',
#   'China',
#   'United',
#   'States',
#   'America',
#   'America',
#   'Medicare',
#   'Social',
#   'Security',
#   'America',
#   'United',
#   'States',
#   'Mars',
#   'NASA',
#   'God',
#   'President',
#   'America',
#   'President',
#   'America',
#   'Nevada',
#   'November',
#   'Carson',
#   'City',
#   'Elko',
#   'Las',
#   'Vegas',
#   'Reno',
#   'Minden',
#   'Henderson',
#   'Nevada',
#   'Hoover',
#   'Dam',
#   'Vegas',
#   'Strip',
#   'Colby',
#   'Justin',
#   'Vegas',
#   'President',
#   'President',
#   'United',
#   'States',
#   'Justin',
#   'Colby',
#   'God',
#   'Nevada',
#   'America',
#   'America',
#   'America',
#   'America',
#   'America'],
#  ['Greenville',
#   'North',
#   'Carolina',
#   'Mike',
#   'Pence',
#   'Vice',
#   'President',
#   'Mike',
#   'North',
#   'Carolina',
#   'United',
#   'States',
#   'House',
#   'Representative',
#   'Democrats',
#   'United',
#   'States',
#   'America',
#   'America',
#   'America',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'Clinton',
#   'North',
#   'Carolina',
#   'November',
#   'Donald',
#   'Trump',
#   'North',
#   'Carolina',
#   'Florida',
#   'South',
#   'Carolina',
#   'South',
#   'Carolina',
#   'Pennsylvania',
#   'Pennsylvania',
#   'Wisconsin',
#   'Michigan',
#   'Asia',
#   'Europe',
#   'Harrell',
#   'African',
#   'Americans',
#   'Hispanic',
#   'Americans',
#   'Hispanic',
#   'American',
#   'Asian',
#   'Americans',
#   'Trump',
#   'Donald',
#   'Trump',
#   'Democrats',
#   'Mr.',
#   'President',
#   'China',
#   'President',
#   'Xi',
#   'China',
#   'Democrat',
#   'Party',
#   'Democrats',
#   'Democrats',
#   'America',
#   'Congress',
#   'Representative',
#   'Ilhan',
#   'Omar',
#   'Minnesota',
#   'Greg',
#   'Stanton',
#   'Omar',
#   'United',
#   'States',
#   'US',
#   'Service',
#   'Black',
#   'Hawk',
#   'Down',
#   'Americans',
#   'Somalia',
#   'Omar',
#   'September',
#   'Omar',
#   'Americans',
#   'Al',
#   'Qaeda',
#   'America',
#   'Al',
#   'Qaeda',
#   'Al',
#   'Qaeda',
#   'America',
#   'Al',
#   'Qaeda',
#   'Omar',
#   'United',
#   'States',
#   'Venezuela',
#   'American',
#   'Omar',
#   'Israel',
#   'Omar',
#   'Omar',
#   'Representative',
#   'Rashida',
#   'Tlaib',
#   'Omar',
#   'Congress',
#   'Israel',
#   'Tlaib',
#   'F',
#   'President',
#   'United',
#   'States',
#   'Representative',
#   'Alexandria',
#   'Ocasio',
#   'Cortez',
#   'Mexico',
#   'Cortez',
#   'sir',
#   'Cortez',
#   'Cortez',
#   'Mike',
#   'Pence',
#   'Congress',
#   'Democrats',
#   'Cortez',
#   'contemporary',
#   'America',
#   'Joe',
#   'Pocahontas',
#   'Pocahontas',
#   'Pocahontas',
#   'Biden',
#   'Republican',
#   'Hillary',
#   'Trump',
#   'Harris',
#   'Buttigieg',
#   'Buttigieg',
#   'Buut',
#   'Mike',
#   'Pence',
#   'Mike',
#   'Mike',
#   'African',
#   'Americans',
#   'Buut',
#   'Buut',
#   'Buttigieg',
#   'President',
#   'Xi',
#   'China',
#   'Kim',
#   'Jong',
#   'un',
#   'Russia',
#   'Donald',
#   'Trump',
#   'Vladimir',
#   'Putin',
#   'NATO',
#   'Europe',
#   'US',
#   'United',
#   'States',
#   'European',
#   'Union',
#   'China',
#   'China',
#   'Biden',
#   'Trump',
#   'Representative',
#   'Ayanna',
#   'Pressle',
#   'Elvis',
#   'North',
#   'Carolina',
#   'Congresswomen',
#   'North',
#   'Carolina',
#   'Congresswomen',
#   'American',
#   'Democrat',
#   'anti',
#   'Democrats',
#   'Democrats',
#   'North',
#   'Carolina',
#   'Lieutenant',
#   'Governor',
#   'Dan',
#   'Forest',
#   'Lieutenant',
#   'Governor',
#   'North',
#   'Carolina',
#   'Treasurer',
#   'Dale',
#   'Folwell',
#   'Greenville',
#   'Mayor',
#   'PJ',
#   'Connelly',
#   'PJ',
#   'North',
#   'Carolina',
#   'GOP',
#   'Chair',
#   'Michael',
#   'Whatley',
#   'NCAA',
#   'Ohio',
#   'Congressman',
#   'Jim',
#   'Jordan',
#   'Congress',
#   'North',
#   'Carolina',
#   'Dr.',
#   'Greg',
#   'Murphy',
#   'Greg',
#   'Greg',
#   'Supreme',
#   'Court',
#   'Greg',
#   'North',
#   'Carolina',
#   'Democrat',
#   'Dan',
#   'McCready',
#   'North',
#   'Carolina',
#   'Congressman',
#   'Dan',
#   'Bishop',
#   'Dan',
#   'Dan',
#   'Dan',
#   'Nancy',
#   'Pelosi',
#   'Obama',
#   'MS-13',
#   'Sunday',
#   'Sunday',
#   'ICE',
#   'United',
#   'States',
#   'Biden',
#   'California',
#   'Los',
#   'Angeles',
#   'San',
#   'Francisco',
#   'Nancy',
#   'Pelosi',
#   'Democrats',
#   'Republican',
#   'Democrats',
#   'United',
#   'States',
#   'Democrats',
#   'Democrats',
#   'Los',
#   'Angeles',
#   'Tillis',
#   'Thom',
#   'merit',
#   'Senate',
#   'Presidency',
#   'Democrats',
#   'Democrats',
#   'Congress',
#   'Bernie',
#   'Sanders',
#   'Democrat',
#   'Bernie',
#   'Bernie',
#   'Bernie',
#   'Bernie',
#   'Rolls',
#   'Royce',
#   'Rolls',
#   'Royce',
#   'Donald',
#   'Trump',
#   'Rolls',
#   'Royce',
#   'Free',
#   'Rolls',
#   'Royce',
#   'Bernie',
#   'North',
#   'Carolina',
#   'North',
#   'Carolina',
#   'Mike',
#   'Eric',
#   'Trump',
#   'Lara',
#   'y',
#   'North',
#   'Carolina',
#   'Lara',
#   'Brad',
#   'Parscale',
#   'Brad',
#   'North',
#   'Carolina',
#   'Ohio',
#   'Biden',
#   'Sleepy',
#   'Joe',
#   'Obamacare',
#   'Republicans',
#   'Democrats',
#   'Democrats',
#   'Pocahontas',
#   'Pocahontas',
#   'Indians',
#   'Trump',
#   'Trump',
#   'Trump',
#   'Trump',
#   'North',
#   'Carolina',
#   'Democrat',
#   'Virginia',
#   'God',
#   'Congress',
#   'Democrats',
#   'Republican',
#   'Party',
#   'Americans',
#   'Republican',
#   'Party',
#   'Republican',
#   'National',
#   'Convention',
#   'Charlotte',
#   'North',
#   'Carolina',
#   'Ohio',
#   'Florida',
#   'Trump',
#   'Trump',
#   'Donald',
#   'Trump',
#   'Dan',
#   'Scavino',
#   'Time',
#   'Magazine',
#   'Trump',
#   'sir',
#   'Senator',
#   'Joyce',
#   'Joyce',
#   'Joyce',
#   'Mr.',
#   'President',
#   'Mr.',
#   'President',
#   'Mr.',
#   'President',
#   'Mr.',
#   'President',
#   'Mr.',
#   'President',
#   'Don',
#   'Donald',
#   'D',
#   'New',
#   'York',
#   'Mr.',
#   'President',
#   'sir',
#   'Richard',
#   'Rich',
#   'hey',
#   'Richard',
#   'Hey',
#   'Don',
#   'Sir',
#   'Richard',
#   'Donald',
#   'Donald',
#   'Donald',
#   'Donald',
#   'Mr',
#   'President',
#   'Neil',
#   'Gorsuch',
#   'Brett',
#   'Kavanaugh',
#   'Democrats',
#   'American',
#   'America',
#   'Americans',
#   'Arnold',
#   'Schwarzenegger',
#   'Apprentice',
#   'United',
#   'States',
#   'Iran',
#   'Iran',
#   'Israel',
#   'American',
#   'Embassy',
#   'Jerusalem',
#   'Golan',
#   'Heights',
#   'Israel',
#   'Golan',
#   'Heights',
#   'Venezuela',
#   'America',
#   'Democrat',
#   'ISIS',
#   'Caliphate',
#   'Syria',
#   'ISIS',
#   'Raisin',
#   'Sir',
#   'Watch',
#   'Sir',
#   'Raisin',
#   'Raisin',
#   'sir',
#   'Kane',
#   'Raisin',
#   'Kane',
#   'Raisin',
#   'Kane',
#   'Raisin',
#   'Kane',
#   'Raisin',
#   'Kane',
#   'Hollywood',
#   'Raisin',
#   'Kane',
#   'General',
#   'Sir',
#   'sir',
#   'Syria',
#   'sir',
#   'Iraq',
#   'sir',
#   'Goddamn',
#   'Caliphate',
#   'Obama',
#   'President',
#   'Obama',
#   'Iraq',
#   'Air',
#   'Force',
#   'One',
#   'Sir',
#   'sir',
#   'sir',
#   'sir',
#   'sir',
#   'Middle',
#   'East',
#   'Air',
#   'Force',
#   'One',
#   'sir',
#   'sir',
#   'Sir',
#   'North',
#   'Carolina',
#   'American',
#   'American',
#   'Republican',
#   'Congress',
#   'Germany',
#   'Obama',
#   'Trump',
#   'Anguilla',
#   'Anguilla',
#   'Anguilla',
#   'Obama',
#   'Anguilla',
#   'Anguilla',
#   'Donald',
#   'Trump',
#   'Europe',
#   'President',
#   'Obama',
#   'President',
#   'Bush',
#   'America',
#   'USA',
#   'America',
#   'America',
#   'America',
#   'God',
#   'God',
#   'America',
#   'America',
#   'America',
#   'America',
#   'America',
#   'America',
#   'MAGA',
#   'MAGA',
#   'America',
#   'America',
#   'America',
#   'America',
#   'Great']]

# %%
# Define function to extract named entities from doc objects
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# Apply function to Doc column and store resulting named entities in new column
speech_df['Named_Entities'] = speech_df['Doc'].apply(extract_named_entities)
speech_df['Named_Entities']
# Out:
# 0     [PERSON, GPE, GPE, GPE, ORDINAL, DATE, GPE, OR...
# 1     [PERSON, TIME, GPE, GPE, PERSON, CARDINAL, DAT...
# 2     [ORG, GPE, ORDINAL, ORDINAL, CARDINAL, CARDINA...
# 3     [GPE, CARDINAL, NORP, DATE, GPE, DATE, FAC, DA...
# 4     [PERSON, GPE, GPE, CARDINAL, NORP, DATE, GPE, ...
# 5     [GPE, GPE, GPE, CARDINAL, DATE, NORP, GPE, TIM...
# 6     [PERSON, DATE, GPE, GPE, GPE, CARDINAL, CARDIN...
# 7     [GPE, GPE, ORG, TIME, TIME, DATE, ORG, GPE, GP...
# 8     [GPE, GPE, CARDINAL, GPE, PERSON, PERSON, GPE,...
# 9     [GPE, GPE, GPE, DATE, LOC, CARDINAL, NORP, DAT...
# 10    [GPE, GPE, PERSON, DATE, GPE, DATE, FAC, PERSO...
# 11    [GPE, TIME, GPE, PERSON, ORG, NORP, NORP, GPE,...
# 12    [CARDINAL, GPE, MONEY, GPE, ORG, GPE, GPE, NOR...
# 13    [GPE, DATE, CARDINAL, CARDINAL, CARDINAL, TIME...
# 14    [PERSON, PERSON, PERSON, PERSON, QUANTITY, PER...
# 15    [PERSON, GPE, GPE, DATE, DATE, DATE, ORDINAL, ...
# 16    [GPE, GPE, CARDINAL, NORP, GPE, DATE, GPE, PER...
# 17    [GPE, GPE, GPE, CARDINAL, ORG, DATE, DATE, DAT...
# 18    [GPE, GPE, PERSON, DATE, DATE, GPE, CARDINAL, ...
# 19    [GPE, GPE, CARDINAL, NORP, GPE, DATE, CARDINAL...
# 20    [PERSON, PERSON, GPE, ORG, ORG, GPE, ORG, ORG,...
# 21    [PERSON, GPE, CARDINAL, NORP, CARDINAL, CARDIN...
# 22    [GPE, DATE, DATE, GPE, DATE, GPE, DATE, DATE, ...
# 23    [CARDINAL, PERSON, ORG, GPE, DATE, GPE, ORG, T...
# 24    [GPE, GPE, GPE, CARDINAL, NORP, DATE, GPE, DAT...
# 25    [GPE, DATE, GPE, GPE, CARDINAL, NORP, CARDINAL...
# 26    [GPE, GPE, CARDINAL, ORG, CARDINAL, DATE, CARD...
# 27    [GPE, CARDINAL, NORP, DATE, GPE, DATE, FAC, PE...
# 28    [GPE, DATE, PERSON, GPE, GPE, DATE, DATE, GPE,...
# 29    [PERSON, PERSON, GPE, ORG, ORG, CARDINAL, NORP...
# 30    [NORP, DATE, DATE, DATE, GPE, DATE, FAC, CARDI...
# 31    [PERSON, GPE, GPE, GPE, GPE, TIME, TIME, NORP,...
# 32    [GPE, GPE, GPE, GPE, CARDINAL, NORP, DATE, DAT...
# 33    [GPE, FAC, FAC, GPE, DATE, GPE, DATE, GPE, CAR...
# 34    [GPE, GPE, PERSON, PERSON, TIME, TIME, CARDINA...
# Name: Named_Entities, dtype: object

# %%
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

# Apply function to Doc column and store resulting text in new column
speech_df['NE_Words'] = speech_df['Doc'].apply(extract_named_entities)
speech_df['NE_Words']
# Out:
# 0     [(Mike, Pence), (Fayetteville), (Fayetteville)...
# 1     [(Tupelo), (tonight), (Mississippi), (Mississi...
# 2     [(Manchester), (New, Hampshire), (third), (fou...
# 3     [(Henderson), (Thousands), (American), (51, da...
# 4     [(Swanton), (Toledo), (Ohio), (thousands), (Am...
# 5     [(Phoenix), (Phoenix), (Arizona), (thousands),...
# 6     [(Pence), (Christmas), (Michigan), (Michigan),...
# 7     [(California), (Pennsylvania), (Trump), (a, fe...
# 8     [(Houston), (Texas), (one), (America), (Modi, ...
# 9     [(Colorado), (Colorado), (Colorado, Springs), ...
# 10    [(Pennsylvania), (Latrobe), (Arnold, Palmer), ...
# 11    [(Dallas), (tonight), (Texas), (Louie, Vuitton...
# 12    [(two), (Japan), (three, ,, 40, billion), (Jap...
# 13    [(Minnesota), (the, day), (20,000, -, plus), (...
# 14    [(Obama), (Joe, Biden), (Art), (Brandon), (122...
# 15    [(Mike, Pence), (Toledo), (Toledo), (2016), (a...
# 16    [(North, Carolina), (Charlotte), (thousands), ...
# 17    [(North, Carolina), (North, Carolina), (Winsto...
# 18    [(Oklahoma), (Oklahoma), (Mike, Pence), (weeks...
# 19    [(New, Mexico), (Albuquerque), (thousands), (A...
# 20    [(Pence), (Mike), (Pennsylvania), (the, Libert...
# 21    [(Manchester), (New, Hampshire), (thousands), ...
# 22    [(Las, Vegas), (tomorrow), (tomorrow), (Iowa),...
# 23    [(thousands), (Manchester), (Manchester), (Man...
# 24    [(Nevada), (Douglas, County), (Douglas, County...
# 25    [(Michigan), (the, last, three, and, a, half, ...
# 26    [(Charleston), (South, Carolina), (thousands),...
# 27    [(Wisconsin), (thousands), (American), (47, da...
# 28    [(Wisconsin), (a, few, years, ago), (Donald, T...
# 29    [(Lee, Greenwood), (Lee), (Kentucky), (Wildcat...
# 30    [(American), (last, year), (the, best, year), ...
# 31    [(Mike, Pence), (Cincinnati), (Cincinnati), (S...
# 32    [(North, Carolina), (North, Carolina), (North,...
# 33    [(New, Jersey), (the, Garden, State), (The, Ga...
# 34    [(Greenville), (North, Carolina), (Mike, Pence...
# Name: NE_Words, dtype: object

# %%
# Extract the first Doc object
doc = speech_df['Doc'][1]

# Visualize named entity tagging in a single speech
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ell, thank you very much. And hello,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tupelo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . This is great to be with you
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tonight
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , the great state of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mississippi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The great state of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mississippi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and by the way, the birthplace of a gentleman, not too many people heard of him,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elvis Presley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . But to be with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of incredible patriots who put their faith in God, family and country. Right?
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four days from now
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , this state will head to the polls and vote to continue our extraordinary progress with your next governor,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tate Reeves
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Great guy. Great guy. Under
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Republican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  leadership, jobs are booming, confidence is soaring, wages are rising, crime is falling, and our nation is stronger than ever before. We're now an economic powerhouse. We've never been in a position like it. We've rebuilt our military and we have financial strength. And by the way, for those of you with a thing called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     401ks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , the stock market hit,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , another all-time historic high. Unemployment in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mississippi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has reached the lowest rate ever recorded, ever recorded. That's not bad. That's not bad when you're on the debate stage and you say, &quot;We have the best economy we've ever had. We have the best military we've ever had, the best unemployment and employment numbers we've ever had.&quot;
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Said
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , &quot;Got the best president we've ever had.&quot; Thank you. Thank you. Thank you.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more years!
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# !
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Four more years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ! Thank you very much. And very importantly, we've confirmed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 158
#     <span style="font-size: 0.8em; fo

# %%
# Save DataFrame as csv (in Google Drive)
# Use this step only to save  csv to your computer's working directory
speech_df.to_csv('Trump_speeches_with_spaCy_tags.csv')

# %%
speech_df
# Out:
#                           Filename  \
# 0        FayettevilleSep9_2019.txt
# 1              TupeloNov1_2019.txt
# 2       NewHampshireAug15_2019.txt
# 3          HendersonSep13_2020.txt
# 4               OhioSep21_2020.txt
# 5            PhoenixFeb19_2020.txt
# 6        BattleCreekDec19_2019.txt
# 7         PittsburghSep22_2020.txt
# 8              TexasSep23_2019.txt
# 9   ColoradorSpringsFeb20_2020.txt
# 10            LatrobeSep3_2020.txt
# 11            DallasOct17_2019.txt
# 12         DesMoinesJan30_2020.txt
# 13       MinneapolisOct10_2019.txt
# 14              YumaAug18_2020.txt
# 15             ToledoJan9_2020.txt
# 16          CharlotteMar2_2020.txt
# 17      Winston-SalemSep8_2020.txt
# 18             TulsaJun20_2020.txt
# 19         NewMexicoSep16_2019.txt
# 20           HersheyDec10_2019.txt
# 21      NewHampshireFeb10_2020.txt
# 22          LasVegasFeb21_2020.txt
# 23      NewHampshireAug28_2020.txt
# 24            MindenSep12_2020.txt
# 25          FreelandSep10_2020.txt
# 26        CharlestonFeb28_2020.txt
# 27           MosineeSep17_2020.txt
# 28         MilwaukeeJan14_2020.txt
# 29          LexingtonNov4_2019.txt
# 30           BemidjiSep18_2020.txt
# 31         CincinnatiAug1_2019.txt
# 32      FayettevilleSep19_2020.txt
# 33          WildwoodJan28_2020.txt
# 34        GreenvilleJul17_2019.txt
#
#                                                  Text  \
# 0    Thank you everybody. Thank you and Vice Presi...
# 1   ell, thank you very much. And hello, Tupelo. T...
# 2    Thank you very much everybody. Thank you. Wow...
# 3   Thank you, thank you. Wow. Wow, and I'm thrill...
# 4   Wow, that's a big crowd. This is a big crowd. ...
# 5    Thank you very much, Phoenix. We love to be b...
# 6   Thank you. Thank you. Thank you to Vice Presid...
# 7   Doesn't have the power. Doesn't have the stayi...
# 8   Hello, Houston. I am so thrilled to be here in...
# 9   Hello Colorado. We love Colorado, most beautif...
# 10  So thank you Pennsylvania, very much. I'm thri...
# 11  Thank you. Thank you very much. Hello Dallas. ...
# 12  I worked so hard for this state. I worked so h...
# 13  Thank you very much. Thank you, Minnesota. Thi...
# 14  Oh, thank you very much, everybody. Thank you....
# 15  Well, thank you very much. Vice President Mike...
# 16  I want to thank you very much. North Carolina,...
# 17  Well, thank you very much. Thank you. Thank yo...
# 18  Thank you, thank you. So we begin, Oklahoma, w...
# 19   Wow, thank you. Thank you, New Mexico. Thank ...
# 20   Well, thank you to Vice President Pence. Than...
# 21  Hello, Manchester, and I am thrilled to be in ...
# 22  Well, thank you very much. And hello Las Vegas...
# 23  Hello, everybody. Hello, everybody. Wow. Hello...
# 24  Well, I thank you very much. So I want to star...
# 25  We brought you a lot of car plants, Michigan. ...
# 26  Thank you. Thank you. Thank you. All I can say...
# 27  Thank you, thank you very much. Thank you very...
# 28  Well thank you very much. And I'm thrilled to ...
# 29  Thank you very much and thank you to the origi...
# 30  There's a lot of people. That's great. Thank y...
# 31  Thank you all. Thank you very much. Thank you ...
# 32  What a crowd, what a crowd. Get those people o...
# 33  Thank you. Thank you. I love New Jersey and I'...
# 34  Thank you very much. Thank you. Thank you. Tha...
#
#                                                   Doc  \
# 0   ( , Thank, you, everybody, ., Thank, you, and,...
# 1   (ell, ,, thank, you, very, much, ., And, hello...
# 2   ( , Thank, you, very, much, everybody, ., Than...
# 3   (Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4   (Wow, ,, that, 's, a, big, crowd, ., This, is,...
# 5   ( , Thank, you, very, much, ,, Phoenix, ., We,...
# 6   (Thank, you, ., Thank, you, ., Thank, you, to,...
# 7   (Does, n't, have, the, power, ., Does, n't, ha...
# 8   (Hello, ,, Houston, ., I, am, so, thrilled, to...
# 9   (Hello, Colorado, ., We, love, Colorado, ,, mo...
# 10  (So, thank, you, Pennsylvania, ,, very, much, ...
# 11  (Thank, you, ., Thank, you, very, much, ., Hel...
# 12  (I, worked, so, hard, for, this, state, ., I, ...
# 13  (Thank, you, very, much, ., Thank, you, ,, Min...
# 14  (Oh, ,, thank, you, very, much, ,, everybody, ...
# 15  (Well, ,, thank, you, very, much, ., Vice, Pre...
# 16  (I, want, to, thank, you, very, much, ., North...
# 17  (Well, ,, thank, you, very, much, ., Thank, yo...
# 18  (Thank, you, ,, thank, you, ., So, we, begin, ...
# 19  ( , Wow, ,, thank, you, ., Thank, you, ,, New,...
# 20  ( , Well, ,, thank, you, to, Vice, President, ...
# 21  (Hello, ,, Manchester, ,, and, I, am, thrilled...
# 22  (Well, ,, thank, you, very, much, ., And, hell...
# 23  (Hello, ,, everybody, ., Hello, ,, everybody, ...
# 24  (Well, ,, I, thank, you, very, much, ., So, I,...
# 25  (We, brought, you, a, lot, of, car, plants, ,,...
# 26  (Thank, you, ., Thank, you, ., Thank, you, ., ...
# 27  (Thank, you, ,, thank, you, very, much, ., Tha...
# 28  (Well, thank, you, very, much, ., And, I, 'm, ...
# 29  (Thank, you, very, much, and, thank, you, to, ...
# 30  (There, 's, a, lot, of, people, ., That, 's, g...
# 31  (Thank, you, all, ., Thank, you, very, much, ....
# 32  (What, a, crowd, ,, what, a, crowd, ., Get, th...
# 33  (Thank, you, ., Thank, you, ., I, love, New, J...
# 34  (Thank, you, very, much, ., Thank, you, ., Tha...
#
#                                                Tokens  \
# 0   [ , Thank, you, everybody, ., Thank, you, and,...
# 1   [ell, ,, thank, you, very, much, ., And, hello...
# 2   [ , Thank, you, very, much, everybody, ., Than...
# 3   [Thank, you, ,, thank, you, ., Wow, ., Wow, ,,...
# 4   [Wow, ,, that, 's, a, big, crowd, ., This, is,...
# 5   [ , Thank, you, very, much, ,, Phoenix, ., We,...
# 6   [Thank, you, ., Thank, you, ., Thank, you, to,...
# 7   [Does, n't, have, the, power, ., Does, n't, ha...
# 8   [Hello, ,, Houston, ., I, am, so, thrilled, to...
# 9   [Hello, Colorado, ., We, love, Colorado, ,, mo...
# 10  [So, thank, you, Pennsylvania, ,, very, much, ...
# 11  [Thank, you, ., Thank, you, very, much, ., Hel...
# 12  [I, worked, so, hard, for, this, state, ., I, ...
# 13  [Thank, you, very, much, ., Thank, you, ,, Min...
# 14  [Oh, ,, thank, you, very, much, ,, everybody, ...
# 15  [Well, ,, thank, you, very, much, ., Vice, Pre...
# 16  [I, want, to, thank, you, very, much, ., North...
# 17  [Well, ,, thank, you, very, much, ., Thank, yo...
# 18  [Thank, you, ,, thank, you, ., So, we, begin, ...
# 19  [ , Wow, ,, thank, you, ., Thank, you, ,, New,...
# 20  [ , Well, ,, thank, you, to, Vice, President, ...
# 21  [Hello, ,, Manchester, ,, and, I, am, thrilled...
# 22  [Well, ,, thank, you, very, much, ., And, hell...
# 23  [Hello, ,, everybody, ., Hello, ,, everybody, ...
# 24  [Well, ,, I, thank, you, very, much, ., So, I,...
# 25  [We, brought, you, a, lot, of, car, plants, ,,...
# 26  [Thank, you, ., Thank, you, ., Thank, you, ., ...
# 27  [Thank, you, ,, thank, you, very, much, ., Tha...
# 28  [Well, thank, you, very, much, ., And, I, 'm, ...
# 29  [Thank, you, very, much, and, thank, you, to, ...
# 30  [There, 's, a, lot, of, people, ., That, 's, g...
# 31  [Thank, you, all, ., Thank, you, very, much, ....
# 32  [What, a, crowd, ,, what, a, crowd, ., Get, th...
# 33  [Thank, you, ., Thank, you, ., I, love, New, J...
# 34  [Thank, you, very, much, ., Thank, you, ., Tha...
#
#                                                Lemmas  \
# 0   [ , thank, you, everybody, ., thank, you, and,...
# 1   [ell, ,, thank, you, very, much, ., and, hello...
# 2   [ , thank, you, very, much, everybody, ., than...
# 3   [thank, you, ,, thank, you, ., wow, ., wow, ,,...
# 4   [wow, ,, that, be, a, big, crowd, ., this, be,...
# 5   [ , thank, you, very, much, ,, Phoenix, ., we,...
# 6   [thank, you, ., thank, you, ., thank, you, to,...
# 7   [do, not, have, the, power, ., do, not, have, ...
# 8   [hello, ,, Houston, ., I, be, so, thrilled, to...
# 9   [hello, Colorado, ., we, love, Colorado, ,, mo...
# 10  [so, thank, you, Pennsylvania, ,, very, much, ...
# 11  [thank, you, ., thank, you, very, much, ., hel...
# 12  [I, work, so, hard, for, this, state, ., I, wo...
# 13  [thank, you, very, much, ., thank, you, ,, Min...
# 14  [oh, ,, thank, you, very, much, ,, everybody, ...
# 15  [well, ,, thank, you, very, much, ., Vice, Pre...
# 16  [I, want, to, thank, you, very, much, ., North...
# 17  [well, ,, thank, you, very, much, ., thank, yo...
# 18  [thank, you, ,, thank, you, ., so, we, begin, ...
# 19  [ , wow, ,, thank, you, ., thank, you, ,, New,...
# 20  [ , well, ,, thank, you, to, Vice, President, ...
# 21  [hello, ,, Manchester, ,, and, I, be, thrilled...
# 22  [well, ,, thank, you, very, much, ., and, hell...
# 23  [hello, ,, everybody, ., hello, ,, everybody, ...
# 24  [well, ,, I, thank, you, very, much, ., so, I,...
# 25  [we, bring, you, a, lot, of, car, plant, ,, Mi...
# 26  [thank, you, ., thank, you, ., thank, you, ., ...
# 27  [thank, you, ,, thank, you, very, much, ., tha...
# 28  [well, thank, you, very, much, ., and, I, be, ...
# 29  [thank, you, very, much, and, thank, you, to, ...
# 30  [there, be, a, lot, of, people, ., that, be, g...
# 31  [thank, you, all, ., thank, you, very, much, ....
# 32  [what, a, crowd, ,, what, a, crowd, ., get, th...
# 33  [thank, you, ., thank, you, ., I, love, New, J...
# 34  [thank, you, very, much, ., thank, you, ., tha...
#
#                                                   POS  \
# 0   [(SPACE, _SP), (VERB, VBP), (PRON, PRP), (PRON...
# 1   [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 2   [(SPACE, _SP), (VERB, VBP), (PRON, PRP), (ADV,...
# 3   [(VERB, VBP), (PRON, PRP), (PUNCT, ,), (VERB, ...
# 4   [(INTJ, UH), (PUNCT, ,), (PRON, DT), (AUX, VBZ...
# 5   [(SPACE, _SP), (VERB, VBP), (PRON, PRP), (ADV,...
# 6   [(VERB, VBP), (PRON, PRP), (PUNCT, .), (VERB, ...
# 7   [(AUX, VBZ), (PART, RB), (VERB, VB), (DET, DT)...
# 8   [(INTJ, UH), (PUNCT, ,), (PROPN, NNP), (PUNCT,...
# 9   [(INTJ, UH), (PROPN, NNP), (PUNCT, .), (PRON, ...
# 10  [(ADV, RB), (VERB, VBP), (PRON, PRP), (PROPN, ...
# 11  [(VERB, VBP), (PRON, PRP), (PUNCT, .), (VERB, ...
# 12  [(PRON, PRP), (VERB, VBD), (ADV, RB), (ADV, RB...
# 13  [(VERB, VBP), (PRON, PRP), (ADV, RB), (ADV, RB...
# 14  [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 15  [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 16  [(PRON, PRP), (VERB, VBP), (PART, TO), (VERB, ...
# 17  [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 18  [(VERB, VBP), (PRON, PRP), (PUNCT, ,), (VERB, ...
# 19  [(SPACE, _SP), (INTJ, UH), (PUNCT, ,), (VERB, ...
# 20  [(SPACE, _SP), (INTJ, UH), (PUNCT, ,), (VERB, ...
# 21  [(INTJ, UH), (PUNCT, ,), (PROPN, NNP), (PUNCT,...
# 22  [(INTJ, UH), (PUNCT, ,), (VERB, VBP), (PRON, P...
# 23  [(INTJ, UH), (PUNCT, ,), (PRON, NN), (PUNCT, ....
# 24  [(INTJ, UH), (PUNCT, ,), (PRON, PRP), (VERB, V...
# 25  [(PRON, PRP), (VERB, VBD), (PRON, PRP), (DET, ...
# 26  [(VERB, VBP), (PRON, PRP), (PUNCT, .), (VERB, ...
# 27  [(VERB, VBP), (PRON, PRP), (PUNCT, ,), (VERB, ...
# 28  [(INTJ, UH), (VERB, VBP), (PRON, PRP), (ADV, R...
# 29  [(VERB, VBP), (PRON, PRP), (ADV, RB), (ADV, RB...
# 30  [(PRON, EX), (VERB, VBZ), (DET, DT), (NOUN, NN...
# 31  [(VERB, VBP), (PRON, PRP), (PRON, DT), (PUNCT,...
# 32  [(PRON, WP), (DET, DT), (NOUN, NN), (PUNCT, ,)...
# 33  [(VERB, VBP), (PRON, PRP), (PUNCT, .), (VERB, ...
# 34  [(VERB, VBP), (PRON, PRP), (ADV, RB), (ADV, RB...
#
#                                          Proper_Nouns  \
# 0   [Vice, President, Mike, Pence, Fayetteville, H...
# 1   [Tupelo, Mississippi, Mississippi, Elvis, Pres...
# 2   [Manchester, New, Hampshire, Patriots, America...
# 3   [Henderson, Nevada, White, House, Los, Angeles...
# 4   [Swanton, Toledo, Ohio, Ohio, Bob, Paduchik, B...
# 5   [Phoenix, Phoenix, Arizona, God, November, Dem...
# 6   [Vice, President, Pence, Merry, Christmas, Mic...
# 7   [California, Pennsylvania, Commonwealth, Penns...
# 8   [Houston, Texas, America, Prime, Minister, Mod...
# 9   [Colorado, Colorado, Colorado, Springs, Rocky,...
# 10  [Pennsylvania, Latrobe, Arnold, Palmer, Common...
# 11  [Dallas, Texas, Louie, Vuitton, Patriots, lone...
# 12  [Japan, Japan, USMCA, China, Des, Moines, Nove...
# 13  [Minnesota, Mike, Pence, Karen, Pence, Twin, C...
# 14  [President, Obama, Joe, Biden, Art, Brandon, G...
# 15  [Vice, President, Mike, Pence, Toledo, Toledo,...
# 16  [North, Carolina, Charlotte, America, North, C...
# 17  [North, Carolina, North, Carolina, Winston, Sa...
# 18  [Oklahoma, Oklahoma, Vice, President, Mike, Pe...
# 19  [New, Mexico, Albuquerque, America, Almighty, ...
# 20  [Vice, President, Pence, Mike, Pennsylvania, L...
# 21  [Manchester, New, Hampshire, God, Democrats, N...
# 22  [Las, Vegas, Iowa, Iowa, Nevada, Nevada, Nevad...
# 23  [Hello, Sir, Manchester, Manchester, Mancheste...
# 24  [Hello, Nevada, Douglas, County, Douglas, Coun...
# 25  [Michigan, Michigan, Freeland, Michigan, White...
# 26  [Charleston, South, Carolina, American, Patrio...
# 27  [hello, Wisconsin, Wisconsin, White, House, Jo...
# 28  [Wisconsin, Donald, Trump, Wisconsin, China, W...
# 29  [Lee, Greenwood, Lee, hello, Kentucky, Wildcat...
# 30  [Minnesota, White, House, Omar, Omar, Minnesot...
# 31  [Vice, President, Mike, Pence, Cincinnati, Cin...
# 32  [North, Carolina, North, Carolina, North, Caro...
# 33  [New, Jersey, Garden, State, Garden, State, Ne...
# 34  [Greenville, North, Carolina, Mike, Pence, Vic...
#
#                                        Named_Entities  \
# 0   [PERSON, GPE, GPE, GPE, ORDINAL, DATE, GPE, OR...
# 1   [PERSON, TIME, GPE, GPE, PERSON, CARDINAL, DAT...
# 2   [ORG, GPE, ORDINAL, ORDINAL, CARDINAL, CARDINA...
# 3   [GPE, CARDINAL, NORP, DATE, GPE, DATE, FAC, DA...
# 4   [PERSON, GPE, GPE, CARDINAL, NORP, DATE, GPE, ...
# 5   [GPE, GPE, GPE, CARDINAL, DATE, NORP, GPE, TIM...
# 6   [PERSON, DATE, GPE, GPE, GPE, CARDINAL, CARDIN...
# 7   [GPE, GPE, ORG, TIME, TIME, DATE, ORG, GPE, GP...
# 8   [GPE, GPE, CARDINAL, GPE, PERSON, PERSON, GPE,...
# 9   [GPE, GPE, GPE, DATE, LOC, CARDINAL, NORP, DAT...
# 10  [GPE, GPE, PERSON, DATE, GPE, DATE, FAC, PERSO...
# 11  [GPE, TIME, GPE, PERSON, ORG, NORP, NORP, GPE,...
# 12  [CARDINAL, GPE, MONEY, GPE, ORG, GPE, GPE, NOR...
# 13  [GPE, DATE, CARDINAL, CARDINAL, CARDINAL, TIME...
# 14  [PERSON, PERSON, PERSON, PERSON, QUANTITY, PER...
# 15  [PERSON, GPE, GPE, DATE, DATE, DATE, ORDINAL, ...
# 16  [GPE, GPE, CARDINAL, NORP, GPE, DATE, GPE, PER...
# 17  [GPE, GPE, GPE, CARDINAL, ORG, DATE, DATE, DAT...
# 18  [GPE, GPE, PERSON, DATE, DATE, GPE, CARDINAL, ...
# 19  [GPE, GPE, CARDINAL, NORP, GPE, DATE, CARDINAL...
# 20  [PERSON, PERSON, GPE, ORG, ORG, GPE, ORG, ORG,...
# 21  [PERSON, GPE, CARDINAL, NORP, CARDINAL, CARDIN...
# 22  [GPE, DATE, DATE, GPE, DATE, GPE, DATE, DATE, ...
# 23  [CARDINAL, PERSON, ORG, GPE, DATE, GPE, ORG, T...
# 24  [GPE, GPE, GPE, CARDINAL, NORP, DATE, GPE, DAT...
# 25  [GPE, DATE, GPE, GPE, CARDINAL, NORP, CARDINAL...
# 26  [GPE, GPE, CARDINAL, ORG, CARDINAL, DATE, CARD...
# 27  [GPE, CARDINAL, NORP, DATE, GPE, DATE, FAC, PE...
# 28  [GPE, DATE, PERSON, GPE, GPE, DATE, DATE, GPE,...
# 29  [PERSON, PERSON, GPE, ORG, ORG, CARDINAL, NORP...
# 30  [NORP, DATE, DATE, DATE, GPE, DATE, FAC, CARDI...
# 31  [PERSON, GPE, GPE, GPE, GPE, TIME, TIME, NORP,...
# 32  [GPE, GPE, GPE, GPE, CARDINAL, NORP, DATE, DAT...
# 33  [GPE, FAC, FAC, GPE, DATE, GPE, DATE, GPE, CAR...
# 34  [GPE, GPE, PERSON, PERSON, TIME, TIME, CARDINA...
#
#                                              NE_Words
# 0   [(Mike, Pence), (Fayetteville), (Fayetteville)...
# 1   [(Tupelo), (tonight), (Mississippi), (Mississi...
# 2   [(Manchester), (New, Hampshire), (third), (fou...
# 3   [(Henderson), (Thousands), (American), (51, da...
# 4   [(Swanton), (Toledo), (Ohio), (thousands), (Am...
# 5   [(Phoenix), (Phoenix), (Arizona), (thousands),...
# 6   [(Pence), (Christmas), (Michigan), (Michigan),...
# 7   [(California), (Pennsylvania), (Trump), (a, fe...
# 8   [(Houston), (Texas), (one), (America), (Modi, ...
# 9   [(Colorado), (Colorado), (Colorado, Springs), ...
# 10  [(Pennsylvania), (Latrobe), (Arnold, Palmer), ...
# 11  [(Dallas), (tonight), (Texas), (Louie, Vuitton...
# 12  [(two), (Japan), (three, ,, 40, billion), (Jap...
# 13  [(Minnesota), (the, day), (20,000, -, plus), (...
# 14  [(Obama), (Joe, Biden), (Art), (Brandon), (122...
# 15  [(Mike, Pence), (Toledo), (Toledo), (2016), (a...
# 16  [(North, Carolina), (Charlotte), (thousands), ...
# 17  [(North, Carolina), (North, Carolina), (Winsto...
# 18  [(Oklahoma), (Oklahoma), (Mike, Pence), (weeks...
# 19  [(New, Mexico), (Albuquerque), (thousands), (A...
# 20  [(Pence), (Mike), (Pennsylvania), (the, Libert...
# 21  [(Manchester), (New, Hampshire), (thousands), ...
# 22  [(Las, Vegas), (tomorrow), (tomorrow), (Iowa),...
# 23  [(thousands), (Manchester), (Manchester), (Man...
# 24  [(Nevada), (Douglas, County), (Douglas, County...
# 25  [(Michigan), (the, last, three, and, a, half, ...
# 26  [(Charleston), (South, Carolina), (thousands),...
# 27  [(Wisconsin), (thousands), (American), (47, da...
# 28  [(Wisconsin), (a, few, years, ago), (Donald, T...
# 29  [(Lee, Greenwood), (Lee), (Kentucky), (Wildcat...
# 30  [(American), (last, year), (the, best, year), ...
# 31  [(Mike, Pence), (Cincinnati), (Cincinnati), (S...
# 32  [(North, Carolina), (North, Carolina), (North,...
# 33  [(New, Jersey), (the, Garden, State), (The, Ga...
# 34  [(Greenville), (North, Carolina), (Mike, Pence...
